# %%
import pandas as pd

PATH_TO_DATA = "hf://datasets/AbhayBhan/SalesData/s1.csv"

df = pd.read_csv(PATH_TO_DATA)

# %%
# total revenue by product category
sales_by_product = df.groupby('Product line')['gross income'].sum().reset_index()
revenue = sales_by_product.sort_values(by='gross income', ascending=False).reset_index(drop=True)
print(revenue)
# Out:
#              Product line  gross income
# 0      Food and beverages     2673.5640
# 1       Sports and travel     2624.8965
# 2  Electronic accessories     2587.5015
# 3     Fashion accessories     2585.9950
# 4      Home and lifestyle     2564.8530
# 5       Health and beauty     2342.5590

# %%
# top 10 dates (in terms of revenue as the data doesn't contain customer name)

sales_by_branch = df.groupby('Date')['gross income'].sum().reset_index()

revenue_by_branch = sales_by_branch.sort_values(by='gross income', ascending=False).reset_index(drop=True)

print(revenue_by_branch[:10])
# Out:
#         Date  gross income
# 0   3/9/2019      355.9070
# 1   2/7/2019      344.2005
# 2  3/14/2019      343.5540
# 3  2/15/2019      325.2755
# 4   3/2/2019      312.3955
# 5   3/5/2019      296.7085
# 6  1/23/2019      285.4375
# 7  1/15/2019      283.0600
# 8  2/27/2019      279.0215
# 9  3/19/2019      273.3520

# %%
import matplotlib.pyplot as plt
import pandas as pd

df["Date"] = pd.to_datetime(df["Date"])
df["Month"] = df["Date"].dt.to_period("M")
monthly_sales = df.groupby("Month")["Total"].sum().reset_index()
monthly_sales["Month"] = monthly_sales["Month"].astype(str)
plt.figure(figsize=(8, 5))

plt.plot(
    monthly_sales["Month"],
    monthly_sales["Total"],
    marker="o",
    color="darkblue",
    linewidth=2,
)


plt.title("Total Monthly Sales Revenue", fontsize=14, fontweight="bold")
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Revenue ($)", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# let's try to visualize weekly sales as monthly sales is very few
df["Week"] = df["Date"].dt.to_period("W")
monthly_sales = df.groupby("Week")["Total"].sum().reset_index()
monthly_sales["Week"] = monthly_sales["Week"].astype(str)
plt.figure(figsize=(15, 8))

plt.plot(
    monthly_sales["Week"],
    monthly_sales["Total"],
    marker="o",
    color="red",
    linewidth=2,
)


plt.title("Total Weekly Sales Revenue", fontsize=20, fontweight="bold")
plt.xlabel("Week", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Total Revenue ($)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %%
sales_by_product = df.groupby('Product line')['gross income'].sum().reset_index()
plt.figure(figsize=(8, 5))
plt.plot(
    sales_by_product['Product line'],
    sales_by_product['gross income'],
    marker="o",
    color="green",
    linewidth=2,
)

plt.title("Total Sales per Product", fontsize=14, fontweight="bold")
plt.xlabel("Month", fontsize=12)
plt.xticks(rotation=45)
plt.ylabel("Total Revenue ($)", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Summary Statistics
summary_stats = df.describe()
summary_stats
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000              1000.000000
# mean   2019-02-14 00:05:45.600000   307.58738                 4.761905
# min           2019-01-01 00:00:00    10.17000                 4.761905
# 25%           2019-01-24 00:00:00   118.49750                 4.761905
# 50%           2019-02-13 00:00:00   241.76000                 4.761905
# ...
